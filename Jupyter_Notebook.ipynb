# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Uma Gayathri Ganesan__

# %% [markdown]
# Data Scientist

# %% [markdown]
# _I am interested in Data Science because Data Science enables enterprises to measure, track, and record performance metrics for facilitating enterprise-wide enhanced decision making._

# %% [markdown]
# ### The below should print 'Hello World'

# %%
print("Hello World")

# %% [markdown]
# #### Cell 6 Work
# ---
# - Subject
# ---
# 1. Maths
# 2. Science
# 3. Social
# ---
# - Language Paper
# ---
# 1. English
# 2. Tamil
# 3. Hindi
# ---
# |Student Name|Language|
# |-|:-:|
# |XXX|Tamil|
# |YYY|English|
# |ZZZ|Hindi|
